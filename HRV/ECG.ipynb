# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

import pyhrv
import pyhrv.time_domain as td
import pyhrv.frequency_domain as fd
import pyhrv.tools as tools

# %%
ECG = pd.read_csv('ECG-BP-waveforms.txt',sep='\t',header=0)
ECG
# Out:
#         Time (s)    ECG  reBAP Markers
# 0          0.000   0.75    0.0     NaN
# 1          0.005   1.00    0.0     NaN
# 2          0.010   0.00    0.0     NaN
# 3          0.015  -1.25    0.0     NaN
# 4          0.020  -1.25    0.0     NaN
# ...          ...    ...    ...     ...
# 209640  1048.200  35.00   84.3     NaN
# 209641  1048.205  35.00   84.0     NaN
# 209642  1048.210  34.50   83.5     NaN
# 209643  1048.215  34.25   83.3     NaN
# 209644  1048.220  35.25   82.8     NaN
#
# [209645 rows x 4 columns]

# %%
plt.plot(ECG['Time (s)'], ECG['ECG']/100)

# %%
tools.plot_ecg(ECG.ECG)
# Out:
# ReturnTuple(ecg_plot=<Figure size 1200x400 with 1 Axes>)

# %%
# Plot ECG
tools.tachogram(signal=ECG.ECG, hr=False)
# Out:
# ReturnTuple(tachogram_plot=<Figure size 1200x400 with 1 Axes>)
